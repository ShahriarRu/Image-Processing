# %% [markdown]
# # Importing Libraries

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Loading Images

# %%
normal_img = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/Random_Image/normal_baby.JPG')
over_exposed_img = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/Random_Image/overexpossed_baby.jpg')
under_exposed_img = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/Random_Image/underexpossed_baby.jpg')
                
normal_img2 = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/Random_Image/normal_building.jpg')
over_exposed_img2 = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/Random_Image/overexpossed_building.jpg')
under_exposed_img2 = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/Random_Image/underexpossed_building.jpg')
                
normal_img3 = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/Random_Image/normal_trees.jpg')
over_exposed_img3 = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/Random_Image/overexpossed_trees.jpg')
under_exposed_img3 = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/Random_Image/underexpossed_trees.jpg')

# %% [markdown]
# # converting to rgb

# %%
normal_grayscale = cv.cvtColor(normal_img,cv.COLOR_RGB2GRAY)
over_exposed_grayscale = cv.cvtColor(over_exposed_img,cv.COLOR_RGB2GRAY)
under_exposed_grayscale = cv.cvtColor(under_exposed_img,cv.COLOR_RGB2GRAY)

normal_grayscale2 = cv.cvtColor(normal_img2,cv.COLOR_RGB2GRAY)
over_exposed_grayscale2 = cv.cvtColor(over_exposed_img2,cv.COLOR_RGB2GRAY)
under_exposed_grayscale2 = cv.cvtColor(under_exposed_img2,cv.COLOR_RGB2GRAY)

normal_grayscale3 = cv.cvtColor(normal_img3,cv.COLOR_RGB2GRAY)
over_exposed_grayscale3 = cv.cvtColor(over_exposed_img3,cv.COLOR_RGB2GRAY)
under_exposed_grayscale3 = cv.cvtColor(under_exposed_img3,cv.COLOR_RGB2GRAY)

# %%
h,w = normal_grayscale.shape

# %%
normal_grayscale = 1 - normal_grayscale

# %% [markdown]
# # Plotting Histograms

# %%
plt.figure(figsize=(30,50))

plt.subplot(9,2,1)
plt.title('Normal')
plt.imshow(normal_grayscale, cmap = 'gray')

plt.subplot(9, 2, 2)
plt.hist(1-normal_grayscale.ravel(), histtype='bar',align='mid',orientation='vertical');

plt.subplot(9,2,3)
plt.title('Normal')
plt.imshow(1-normal_grayscale2, cmap = 'gray')

plt.subplot(9, 2, 4)
plt.hist(1-normal_grayscale2.ravel(),    histtype='bar',align='mid',orientation='vertical');

plt.subplot(9,2,5)
plt.title('Normal')
plt.imshow(1-normal_grayscale3, cmap = 'gray')

plt.subplot(9, 2, 6)
plt.hist(1-normal_grayscale3.ravel(),  histtype='bar',align='mid',orientation='vertical');



plt.subplot(9,2,7)
plt.title('OverExposed')
plt.imshow(1-over_exposed_grayscale, cmap = 'gray')

plt.subplot(9, 2, 8)
plt.hist(1-over_exposed_grayscale.ravel(),  histtype='bar',align='mid',orientation='vertical');


plt.subplot(9,2,9)
plt.title('OverExposed')
plt.imshow(1-over_exposed_grayscale2, cmap = 'gray')

plt.subplot(9, 2, 10)
plt.hist(1-over_exposed_grayscale2.ravel(), histtype='bar',align='mid',orientation='vertical',);


plt.subplot(9,2,11)
plt.title('OverExposed')
plt.imshow(1-over_exposed_grayscale3, cmap = 'gray')

plt.subplot(9, 2, 12)
plt.hist(1-over_exposed_grayscale3.ravel(), histtype='bar',align='mid',orientation='vertical');


plt.subplot(9,2,13)
plt.title('UnderExposed')
plt.imshow(1-under_exposed_grayscale, cmap = 'gray')

plt.subplot(9, 2, 14)
plt.hist(1-under_exposed_grayscale.ravel(), histtype='bar',align='mid',orientation='vertical');

plt.subplot(9,2,15)
plt.title('UnderExposed')
plt.imshow(1-under_exposed_grayscale2, cmap = 'gray')

plt.subplot(9, 2, 16)
plt.hist(1-under_exposed_grayscale2.ravel(), histtype='bar',align='mid',orientation='vertical');


plt.subplot(9,2,17)
plt.title('UnderExposed')
plt.imshow(1-under_exposed_grayscale3, cmap = 'gray')

plt.subplot(9, 2, 18)
plt.hist(1-under_exposed_grayscale3.ravel(),  histtype='bar',align='mid',orientation='vertical');

plt.show()
