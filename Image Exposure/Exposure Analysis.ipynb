# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
normal_img = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/normal/NL_002.png')
over_exposed_img = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/overexposed/NL_002.png')
under_exposed_img = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/underexposed/NL_002.png')
                
normal_img2 = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/normal/NL_005.png')
over_exposed_img2 = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/overexposed/NL_005.png')
under_exposed_img2 = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/underexposed/NL_005.png')
                
normal_img3 = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/normal/NL_009.png')
over_exposed_img3 = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/overexposed/NL_009.png')
under_exposed_img3 = plt.imread('C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Image Exposure/images/underexposed/NL_009.png')

# %%
normal_grayscale = cv.cvtColor(normal_img,cv.COLOR_RGB2GRAY)
over_exposed_grayscale = cv.cvtColor(over_exposed_img,cv.COLOR_RGB2GRAY)
under_exposed_grayscale = cv.cvtColor(under_exposed_img,cv.COLOR_RGB2GRAY)

normal_grayscale2 = cv.cvtColor(normal_img2,cv.COLOR_RGB2GRAY)
over_exposed_grayscale2 = cv.cvtColor(over_exposed_img2,cv.COLOR_RGB2GRAY)
under_exposed_grayscale2 = cv.cvtColor(under_exposed_img2,cv.COLOR_RGB2GRAY)

normal_grayscale3 = cv.cvtColor(normal_img3,cv.COLOR_RGB2GRAY)
over_exposed_grayscale3 = cv.cvtColor(over_exposed_img3,cv.COLOR_RGB2GRAY)
under_exposed_grayscale3 = cv.cvtColor(under_exposed_img3,cv.COLOR_RGB2GRAY)

# %%
h,w = normal_grayscale.shape

# %%
plt.figure(figsize=(30,50))

plt.subplot(9,2,1)
plt.title('Normal')
plt.imshow(normal_grayscale, cmap = 'gray')

plt.subplot(9, 2, 2)
plt.hist(normal_grayscale.ravel(),  range=[0,1], histtype='bar',align='mid',orientation='vertical');

plt.subplot(9,2,3)
plt.title('Normal')
plt.imshow(normal_grayscale2, cmap = 'gray')

plt.subplot(9, 2, 4)
plt.hist(normal_grayscale2.ravel(),  range=[0,1],  histtype='bar',align='mid',orientation='vertical');

plt.subplot(9,2,5)
plt.title('Normal')
plt.imshow(normal_grayscale3, cmap = 'gray')

plt.subplot(9, 2, 6)
plt.hist(normal_grayscale3.ravel(), range=[0,1], histtype='bar',align='mid',orientation='vertical');



plt.subplot(9,2,7)
plt.title('OverExposed')
plt.imshow(over_exposed_grayscale, cmap = 'gray')

plt.subplot(9, 2, 8)
plt.hist(over_exposed_grayscale.ravel(), range=[0,1], histtype='bar',align='mid',orientation='vertical');


plt.subplot(9,2,9)
plt.title('OverExposed')
plt.imshow(over_exposed_grayscale2, cmap = 'gray')

plt.subplot(9, 2, 10)
plt.hist(over_exposed_grayscale2.ravel(), range=[0,1], histtype='bar',align='mid',orientation='vertical',);


plt.subplot(9,2,11)
plt.title('OverExposed')
plt.imshow(over_exposed_grayscale3, cmap = 'gray')

plt.subplot(9, 2, 12)
plt.hist(over_exposed_grayscale3.ravel(), range=[0,1], histtype='bar',align='mid',orientation='vertical');


plt.subplot(9,2,13)
plt.title('UnderExposed')
plt.imshow(under_exposed_grayscale, cmap = 'gray')

plt.subplot(9, 2, 14)
plt.hist(under_exposed_grayscale.ravel(), range=[0,1], histtype='bar',align='mid',orientation='vertical');

plt.subplot(9,2,15)
plt.title('UnderExposed')
plt.imshow(under_exposed_grayscale2, cmap = 'gray')

plt.subplot(9, 2, 16)
plt.hist(under_exposed_grayscale2.ravel(), range=[0,1], histtype='bar',align='mid',orientation='vertical');


plt.subplot(9,2,17)
plt.title('UnderExposed')
plt.imshow(under_exposed_grayscale3, cmap = 'gray')

plt.subplot(9, 2, 18)
plt.hist(under_exposed_grayscale3.ravel(), range=[0,1],  histtype='bar',align='mid',orientation='vertical');

plt.show()
