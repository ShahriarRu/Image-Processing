# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
img_path = "C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Practice/images/bird2.jpg"
img_path
# Out:
# 'C:/Users/Asus/OneDrive/Documents/MyWebProjects/Image Processing/Practice/images/bird2.jpg'

# %%
img = cv2.imread(img_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
grayscale = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)

# %%
width,height = grayscale.shape
print(width,height)
# Out:
# 853 1280

# %%
black = np.zeros((width,height), dtype = 'uint8')

# %%
cv.circle()

# %%
plt.figure(figsize=(25,15))
plt.subplot(2,2,1)
plt.title('RGB')
plt.imshow(img_rgb)

plt.subplot(2,2,2)
plt.title('GRAYSCALE')
plt.imshow(grayscale, cmap='gray')

plt.subplot(2,2,3)
plt.title('Black')
plt.imshow(black, cmap='gray')



plt.show()
