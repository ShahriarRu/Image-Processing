# %% [markdown]
# # Importing Libraries

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
img_path = 'images/minions.jpg'

# %%
rgb = plt.imread(img_path)

# %%
gray = cv2.cvtColor(rgb, cv2.COLOR_RGB2GRAY)

# %%
gray.shape
# Out:
# (1276, 1920)

# %%
ft_img = np.fft.fft2(gray)
centered_ftimg = np.fft.fftshift(ft_img)
magnitude_spectrum = 100 * np.log(np.abs(ft_img))
centered_magnitude_spectrum = 100 * np.log(np.abs(centered_ftimg))

# %%
ft_img.shape
centered_ftimg.shape
magnitude_spectrum.shape
centered_magnitude_spectrum.shape
# Out:
# (1276, 1920)

# %%
def matplotlib_plot_img(img_set, title_set):
    plt.rcParams.update({'font.size': 22})
    
    plt.figure(figsize = (20, 20))
    n = len(img_set)
    for i in range(n):
        plt.subplot(2, 2, i + 1)
        plt.title(title_set[i])
        img = img_set[i]
        ch = len(img.shape)
        if (ch == 2):
            plt.imshow(img, cmap = 'gray')
        else:
            plt.imshow(img)

    plt.tight_layout()
    plt.show()

# %%
img_set = [rgb, gray, centered_ftimg, centered_magnitude_spectrum]
title_set = ['RGB', 'GRAY', 'Centered_ftimg', 'Centered Magnitude Spectrum']
matplotlib_plot_img(img_set, title_set)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 3>()
#       1 img_set = [rgb, gray, centered_ftimg, centered_magnitude_spectrum]
#       2 title_set = ['RGB', 'GRAY', 'Centered_ftimg', 'Centered Magnitude Spectrum']
# ----> 3 matplotlib_plot_img(img_set, title_set)
#
# Input In [30], in matplotlib_plot_img(img_set, title_set)
#      10 ch = len(img.shape)
#      11 if (ch == 2):
# ---> 12     plt.imshow(img, cmap = 'gray')
#      13 else:
#      14     plt.imshow(img)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
# ...
